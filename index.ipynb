# %%
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('causes_of_death.tsv', delimiter='\t')
print(len(df))
df.head()
# Out:
# 4115
#    Notes    State  State Code Ten-Year Age Groups Ten-Year Age Groups Code  \
# 0    NaN  Alabama           1            < 1 year                        1
# 1    NaN  Alabama           1            < 1 year                        1
# 2    NaN  Alabama           1            < 1 year                        1
# 3    NaN  Alabama           1            < 1 year                        1
# 4    NaN  Alabama           1            < 1 year                        1
#
#    Gender Gender Code                              Race Race Code  Deaths  \
# 0  Female           F  American Indian or Alaska Native    1002-5      14
# 1  Female           F         Asian or Pacific Islander      A-PI      24
# 2  Female           F         Black or African American    2054-5    2093
# 3  Female           F                             White    2106-3    2144
# 4    Male           M         Asian or Pacific Islander      A-PI      33
#
#   Population  Crude Rate
# 0       3579  Unreliable
# 1       7443       322.5
# 2     169339      1236.0
# 3     347921       616.2
# 4       7366       448.0

# %% [markdown]
# # Practice Explorations

# %% [markdown]
# ### Groupby State and Sum the numeric features.

# %%
# Groupby State
grouped = df.groupby('State')
grouped.head()
# Out:
#       Notes          State  State Code Ten-Year Age Groups  \
# 0       NaN        Alabama           1            < 1 year
# 1       NaN        Alabama           1            < 1 year
# 2       NaN        Alabama           1            < 1 year
# 3       NaN        Alabama           1            < 1 year
# 4       NaN        Alabama           1            < 1 year
# 81      NaN         Alaska           2            < 1 year
# 82      NaN         Alaska           2            < 1 year
# 83      NaN         Alaska           2            < 1 year
# 84      NaN         Alaska           2            < 1 year
# 85      NaN         Alaska           2            < 1 year
# 163     NaN        Arizona           4            < 1 year
# 164     NaN        Arizona           4            < 1 year
# 165     NaN        Arizona           4            < 1 year
# 166     NaN        Arizona           4            < 1 year
# 167     NaN        Arizona           4            < 1 year
# 255     NaN       Arkansas           5            < 1 year
# 256     NaN       Arkansas           5            < 1 year
# 257     NaN       Arkansas           5            < 1 year
# 258     NaN       Arkansas           5            < 1 year
# 259     NaN       Arkansas           5            < 1 year
# 336     NaN     California           6            < 1 year
# 337     NaN     California           6            < 1 year
# 338     NaN     California           6            < 1 year
# 339     NaN     California           6            < 1 year
# 340     NaN     California           6            < 1 year
# 430     NaN       Colorado           8            < 1 year
# 431     NaN       Colorado           8            < 1 year
# 432     NaN       Colorado           8            < 1 year
# 433     NaN       Colorado           8            < 1 year
# 434     NaN       Colorado           8            < 1 year
# ...     ...            ...         ...                 ...
# 3675    NaN        Vermont          50            < 1 year
# 3676    NaN        Vermont          50            < 1 year
# 3677    NaN        Vermont          50           1-4 years
# 3678    NaN        Vermont          50           1-4 years
# 3679    NaN        Vermont          50          5-14 years
# 3724    NaN       Virginia          51            < 1 year
# 3725    NaN       Virginia          51            < 1 year
# 3726    NaN       Virginia          51            < 1 year
# 3727    NaN       Virginia          51            < 1 year
# 3728    NaN       Virginia          51            < 1 year
# 3809    NaN     Washington          53            < 1 year
# 3810    NaN     Washington          53            < 1 year
# 3811    NaN     Washington          53            < 1 year
# 3812    NaN     Washington          53            < 1 year
# 3813    NaN     Washington          53            < 1 year
# 3898    NaN  West Virginia          54            < 1 year
# 3899    NaN  West Virginia          54            < 1 year
# 3900    NaN  West Virginia          54            < 1 year
# 3901    NaN  West Virginia          54            < 1 year
# 3902    NaN  West Virginia          54           1-4 years
# 3960    NaN      Wisconsin          55            < 1 year
# 433                              White    2106-3    2522     509758
# 434   American Indian or Alaska Native    1002-5      54      12834
# ...                                ...       ...     ...        ...
# 3675                             White    2106-3     222      51212
# 3676                             White    2106-3     320      55207
# 3677                             White    2106-3      40     215509
# 3678                             White    2106-3      44     228680
# 3679                             White    2106-3      74     634852
# 3724  American Indian or Alaska Native    1002-5      15       4785
# 3725         Asian or Pacific Islander      A-PI     211      58646
# 3726         Black or African American    2054-5    2419     209296
# 3727                             White    2106-3    3004     609734
# 3728  American Indian or Alaska Native    1002-5      21       4839
# 3809  American Indian or Alaska Native    1002-5     148      25601
# 3810         Asian or Pacific Islander      A-PI     242      67675
# 3811         Black or African American    2054-5     367      53112
# 3812                             White    2106-3    2635     600970
# 3813  American Indian or Alaska Native    1002-5     218      27168
# 3898         Black or African American    2054-5     107       9823
# 3899                             White    2106-3    1103     170851
# 3900         Black or African American    2054-5     138      10358
# 3901                             White    2106-3    1447     178003
# 3902         Black or African American    2054-5      15      37859
# 3960  American Indian or Alaska Native    1002-5      64      12300
# 3961         Asian or Pacific Islander      A-PI     117      22229
# 3962         Black or African American    2054-5     912      67980
# 3963                             White    2106-3    2450     503270
# 3964  American Indian or Alaska Native    1002-5      94      11967
# 4048  American Indian or Alaska Native    1002-5      19       3260
# 4049                             White    2106-3     327      57791
# 4050  American Indian or Alaska Native    1002-5      41       3366
# 4051         Black or African American    2054-5      11       1572
# 4052                             White    2106-3     415      60874
#
#       Crude Rate
# 0     Unreliable
# 1          322.5
# 2         1236.0
# 3          616.2
# 4          448.0
# 81         903.8
# 82         514.0
# 83         472.8
# 84         458.4
# 85        1184.0
# 163        674.2
# 164        375.9
# 165        975.7
# 166        554.0
# 167        754.0
# 255        579.0
# 256       1090.5
# 257        616.2
# 258   Unreliable
# 259        738.2
# 336        168.0
# 337        349.7
# 338        869.5
# 339        452.5
# 340        241.1
# 430        232.2
# 431        381.8
# 432       1066.5
# 433        494.7
# 434        420.8
# ...          ...
# 3675       433.5
# 3676       579.6
# 3677        18.6
# 3678        19.2
# 3679        11.7
# 3724  Unreliable
# 3725       359.8
# 3726      1155.8
# 3727       492.7
# 3728       434.0
# 3809       578.1
# 3810       357.6
# 3811       691.0
# 3812       438.5
# 3813       802.4
# 3898      1089.3
# 3899       645.6
# 3900      1332.3
# 3901       812.9
# 3902  Unreliable
# 3960       520.3
# 3961       526.3
# 3962      1341.6
# 3963       486.8
# 3964       785.5
# 4048  Unreliable
# 4049       565.8
# 4050      1218.1
# 4051  Unreliable
# 4052       681.7
#
# [255 rows x 12 columns]

# %% [markdown]
# ### Calculate the Correlation Coefficient between the Deaths and Population Columns (of your grouped dataframe)

# %%
#Your code here

# %% [markdown]
# ### Repeat this process across multiple features
# Iterate over the following columns: ['Race', 'Gender', 'Ten-Year Age Groups']. Within your for loop, create a temporary groupby aggregate as we did for the State column above. Then, print any aggregate grouping where the correlation coefficient is less then .95.

# %%
#Your code here

# %% [markdown]
# ### Combining Features
#
# We can further expand upon our exploration above by testing multiple features against each other!
# Complete the code below to print any combination of features where the correlation between population and death is below .95 (or some other appropriate threshold).

# %%
#This could also be accomplished with the combinations() method from the itertools package.
for n, feat1 in enumerate(features):
    for feat2 in features[n:]:
        #Your code here
        #groupby feat1 and feat2!!
        #repeat your code above to check if the correlation is below a [high] threshold.
